# %%
import sqlite3, pandas as pd

# %%
con = sqlite3.connect("domain_tagger.db")

# %%
# See all runs
pd.read_sql("SELECT * FROM runs", con)
# Out:
#      run_id            run_name                     source  \
# 0  68658ac3  Run — 28 Mar 18:17  {"source": "file_upload"}
#
#                                        domain_labels  threshold  \
# 0  ["Accounts", "Customer", "Email", "Employee", ...       0.25
#
#          created_at
# 0  2026-03-28 18:17

# %%
# Full results for a specific run
pd.read_sql("SELECT * FROM tagging_results WHERE run_id = '68658ac3'", con)
# Out:
#       id    run_id                  table_name   domain auto_domain  score  \
# 0      1  68658ac3                sales_orders    Sales       Sales  0.900
# 1      2  68658ac3            order_line_items    Sales       Sales  0.718
# 2      3  68658ac3                order_header    Sales       Sales  0.864
# 3      4  68658ac3               order_details    Sales       Sales  0.897
# 4      5  68658ac3          sales_transactions    Sales       Sales  0.686
# ..   ...       ...                         ...      ...         ...    ...
# 495  496  68658ac3             research_grants  Student     Student  0.854
# 496  497  68658ac3             student_housing  Student     Student  0.894
# 497  498  68658ac3  extracurricular_activities  Student     Student  0.888
# 498  499  68658ac3              alumni_records  Student     Student  0.889
# 499  500  68658ac3     admissions_applications  Student     Student  0.857
#
#                                                columns  \
# 0    ["probability", "order_date", "lead_source", "...
# 1    ["discount_pct", "close_date", "opportunity_id...
# 2    ["stage", "channel", "sales_rep_id", "lead_sou...
# 3    ["unit_price", "probability", "attainment_pct"...
# 4    ["probability", "campaign_id", "opportunity_id...
# ..                                                 ...
# 495  ["graduation_date", "attendance_pct", "departm...
# 496  ["gpa", "section", "major", "credits", "room_n...
# 497  ["tuition_amount", "gpa", "attendance_pct", "d...
# 498  ["aid_amount", "scholarship_name", "exam_score...
# 499  ["student_id", "aid_amount", "department", "ma...
#
#                                              text_used
# 0    sales_orders probability order_date lead_sourc...
# 1    order_line_items discount_pct close_date oppor...
# 2    order_header stage channel sales_rep_id lead_s...
# 3    order_details unit_price probability attainmen...
# 4    sales_transactions probability campaign_id opp...
# ..                                                 ...
# 495  research_grants graduation_date attendance_pct...
# 496  student_housing gpa section major credits room...
# 497  extracurricular_activities tuition_amount gpa ...
# 498  alumni_records aid_amount scholarship_name exa...
# 499  admissions_applications student_id aid_amount ...
#
# [500 rows x 8 columns]

# %%
# All overrides
pd.read_sql("SELECT * FROM user_overrides", con)
# Out:
# Empty DataFrame
# Columns: [id, run_id, table_name, new_domain, overridden_at]
# Index: []

# %%
# Trino check
from trino.dbapi import connect
from trino.auth import BasicAuthentication
import pandas as pd
import numpy as np
from datetime import datetime
 
# Connect to Trino
conn = connect(
    host="tcp.known-racer.mydataos.com",
    port=7432,
    auth=BasicAuthentication("gunasekaranraja", "ZGF0YV9tb2RlbGVyLmM0MTQ0MzU0LWNhYmYtNDM0Zi1iYzFhLTI1OWFjYTFlMTYxMA=="),
    http_scheme="https",
    http_headers={"cluster-name": "minervac"}
)
 
# Query devices
query = """ 
SELECT
    d_id as device_id
FROM
    "icebase"."customer_360".customer
"""
device_df = pd.read_sql(query, conn)
 
 
print(device_df.head(20))
print(device_df.columns)
# device_df.to_csv("disk_failure_prediction.csv",index=False)
# Out:
# C:\Users\Nivedhaa\AppData\Local\Temp\ipykernel_8944\4255080856.py:24: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   device_df = pd.read_sql(query, conn)
# ---------------------------------------------------------------------------
# TrinoUserError                            Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trino\dbapi.py:640, in Cursor.execute(self, operation, params)
#     638     self._query = trino.client.TrinoQuery(self._request, query=operation,
#     639                                           legacy_primitive_types=self._legacy_primitive_types)
# --> 640     self._iterator = iter(self._query.execute())
#     641 return self
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trino\client.py:909, in TrinoQuery.execute(self, additional_http_headers)
#     908 while not self.finished and not self.cancelled and len(self._result.rows) == 0:
# --> 909     self._result.rows += self.fetch()
#     910 return self._result
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trino\client.py:929, in TrinoQuery.fetch(self)
#     928     raise trino.exceptions.TrinoConnectionError("failed to fetch: {}".format(e))
# --> 929 status = self._request.process(response)
#     930 self._update_state(status)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trino\client.py:698, in TrinoRequest.process(self, http_response)
#     697 if "error" in response and response["error"]:
# --> 698     raise self._process_error(response["error"], response.get("id"))
#     700 if constants.HEADER_CLEAR_SESSION in http_response.headers:
#
# TrinoUserError: TrinoUserError(type=USER_ERROR, name=COLUMN_NOT_FOUND, message="line 3:5: Column 'd_id' cannot be resolved", query_id=20260330_111600_01486_q8p5j)
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:2678, in SQLiteDatabase.execute(self, sql, params)
#    2677 try:
# -> 2678     self.con.rollback()
#    2679 except Exception as inner_exc:  # pragma: no cover
#
# File ~\AppData\Roaming\Python\Python313\site-packages\trino\dbapi.py:275, in Connection.rollback(self)
#     274 if self.transaction is None:
# --> 275     raise RuntimeError("no transaction was started")
#     276 self._transaction.rollback()
#
# RuntimeError: no transaction was started
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[1], line 24
#      17 # Query devices
#      18 query = """
#      19 SELECT
#      20     d_id as device_id
#      21 FROM
#      22     "icebase"."customer_360".customer
#      23 """
# ---> 24 device_df = pd.read_sql(query, conn)
#      27 print(device_df.head(20))
#      28 print(device_df.columns)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:706, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704 with pandasSQL_builder(con) as pandas_sql:
#     705     if isinstance(pandas_sql, SQLiteDatabase):
# --> 706         return pandas_sql.read_query(
#     707             sql,
#     708             index_col=index_col,
#     709             params=params,
#     710             coerce_float=coerce_float,
#     711             parse_dates=parse_dates,
#     712             chunksize=chunksize,
#     713             dtype_backend=dtype_backend,
#     714             dtype=dtype,
#     715         )
#     717     try:
#     718         _is_table_name = pandas_sql.has_table(sql)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:2738, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2727 def read_query(
#    2728     self,
#    2729     sql,
#    (...)
#    2736     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737 ) -> DataFrame | Iterator[DataFrame]:
# -> 2738     cursor = self.execute(sql, params)
#    2739     columns = [col_desc[0] for col_desc in cursor.description]
#    2741     if chunksize is not None:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:2683, in SQLiteDatabase.execute(self, sql, params)
#    2679 except Exception as inner_exc:  # pragma: no cover
#    2680     ex = DatabaseError(
#    2681         f"Execution failed on sql: {sql}\n{exc}\nunable to rollback"
#    2682     )
# -> 2683     raise ex from inner_exc
#    2685 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
#    2686 raise ex from exc
#
# DatabaseError: Execution failed on sql:
# SELECT
#     d_id as device_id
# FROM
#     "icebase"."customer_360".customer
#
# TrinoUserError(type=USER_ERROR, name=COLUMN_NOT_FOUND, message="line 3:5: Column 'd_id' cannot be resolved", query_id=20260330_111600_01486_q8p5j)
# unable to rollback

# %%
from trino.dbapi import connect
from trino.auth import BasicAuthentication
import pandas as pd

# Connect to Trino
conn = connect(
    host="tcp.known-racer.mydataos.com",
    port=7432,
    auth=BasicAuthentication(
        "gunasekaranraja",
        "ZGF0YV9tb2RlbGVyLmM0MTQ0MzU0LWNhYmYtNDM0Zi1iYzFhLTI1OWFjYTFlMTYxMA=="
    ),
    http_scheme="https",
    http_headers={"cluster-name": "minervac"}
)

# Execute query
cur = conn.cursor()
cur.execute("""
                SELECT * FROM "icebase"."customer_360".customer LIMIT 10
            """)

# Get column names from cursor description
column_names = [desc[0] for desc in cur.description]

# Fetch rows and convert to DataFrame
rows = cur.fetchall()
df = pd.DataFrame(rows, columns=column_names)

# df
# Save to CSV
# df.to_csv("manage_upload.csv", index=False)

# Print the DataFrame
# print(df)
df
# Out:
#    customer_id external_customer_ref first_name last_name  \
# 0            1         CUST-00000001     Daniel      Hill
# 1            2         CUST-00000002     Robert    Wright
# 2            3         CUST-00000003     Teresa  Ferguson
# 3            4         CUST-00000004    Jessica      Ford
# 4            5         CUST-00000005    Bradley     Mcgee
# 5            6         CUST-00000006   Michelle    Burton
# 6            7         CUST-00000007     Nicole      Read
# 7            8         CUST-00000008   Mohammad     Brown
# 8            9         CUST-00000009      Larry    Santos
# 9           10         CUST-00000010      Amber     Walls
#
#                                      email             phone_e164  birth_date  \
# 0                daniel.hill.227@doyle.net       001-260-501-3389  1985-08-10
# 1              robert.wright.282@wolfe.com           651.216.1559  1973-08-11
# 2            teresa.ferguson.972@hurst.com  +1-634-313-1647x52553  1984-09-01
# 3              jessica.ford.753@holmes.com             9568413953  1973-07-29
# 4  bradley.mcgee.642@burgess-patterson.org          +441314960328  1950-05-24
# 5     michelle.burton.570@carlson-cruz.org        (0191) 496 0480  1990-01-26
# 6              nicole.read.996@harris.info  001-248-728-1489x3252  1945-11-23
# 7            mohammad.brown.805@miller.com           927 824 8963  1988-02-16
# 8               larry.santos.714@price.com    (439) 301-0310 x518  1986-10-24
# 9              amber.walls.153@kennedy.com           865-766-7010  1960-05-01
#
#    gender country_code signup_channel                   signup_at  is_active  \
# 0  female           GB            web  2024-03-09 22:32:44.879081      False
# 1  female           GB          store  2025-08-22 22:32:44.879081       True
# 2  female           US            web  2023-12-11 22:32:44.879081       True
# 3  female           CA            web  2025-06-28 22:32:44.879081       True
# 4    male           US            app  2025-08-05 22:32:44.879081       True
# 5  female           GB            web  2025-07-23 22:32:44.879081       True
# 6    male           IT      marketing  2025-07-30 22:32:44.879081       True
# 7    male           GB            app  2025-06-28 22:32:44.879081      False
# 8    male           IT            web  2025-05-01 22:32:44.879081       True
# 9  female           CA            web  2025-06-26 22:32:44.879081       True
#
#                    created_at                  updated_at
# 0  2024-03-09 22:32:44.879081  2024-03-09 22:32:44.879081
# 1  2025-08-22 22:32:44.879081  2025-08-22 22:32:44.879081
# 2  2023-12-11 22:32:44.879081  2023-12-11 22:32:44.879081
# 3  2025-06-28 22:32:44.879081  2025-06-28 22:32:44.879081
# 4  2025-08-05 22:32:44.879081  2025-08-05 22:32:44.879081
# 5  2025-07-23 22:32:44.879081  2025-07-23 22:32:44.879081
# 6  2025-07-30 22:32:44.879081  2025-07-30 22:32:44.879081
# 7  2025-06-28 22:32:44.879081  2025-06-28 22:32:44.879081
# 8  2025-05-01 22:32:44.879081  2025-05-01 22:32:44.879081
# 9  2025-06-26 22:32:44.879081  2025-06-26 22:32:44.879081
